# %%
#Import your dependencies
import pandas as pd

#Path your csv file
startup_path = "datasets/rob_Best_Cities_for_Startups.csv"

#Create the df from the csv file you are using
startup_df = pd.read_csv(startup_path)
startup_df
# Out:
#      position change in position from 2020               city  \
# 0           1                            0  San Francisco Bay
# 1           2                            0           New York
# 2           3                            3            Beijing
# 3           4                            1   Los Angeles Area
# 4           5                            2             London
# ..        ...                          ...                ...
# 995       996                           26        Ouagadougou
# 996       997                          new            Baghdad
# 997       998                           13            Mbabane
# 998       999                          new            Conakry
# 999      1000                          new              Sanaa
#
#              country  total score  quatity score  quality score  \
# 0      United States      328.966          29.14         296.02
# 1      United States      110.777          11.43          95.55
# ...

# %%
#We are only looking at the top position cities in the united states
startup_df.loc[startup_df['country'] == " United States"].head(5)
# Out:
#     position change in position from 2020               city         country  \
# 0          1                            0  San Francisco Bay   United States
# 1          2                            0           New York   United States
# 3          4                            1   Los Angeles Area   United States
# 5          6                            2        Boston Area   United States
# 11        12                            1            Seattle   United States
#
#     total score  quatity score  quality score  business score  \
# 0       328.966          29.14         296.02             3.8
# 1       110.777          11.43          95.55             3.8
# 3        58.441          11.23          43.41             3.8
# 5        49.835           5.50          40.53             3.8
# 11       24.329           3.49          17.04             3.8
#
#    sign of change in position
# 0                         NaN
# 1                         NaN
# 3                           +
# ...
