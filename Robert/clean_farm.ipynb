# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1. Based on all the final models and figures we can see that there is a strong correlation between weight and tumor volume.
#     The heavier the mice were the greater their tumor volume was.
# 2. An evenly distributed amount of mice were male and female in order to have more scientifically sound findings.
# 3. When looking at the drug regimen 'Capomulin', mouse s185 was shown to have positive improvements according to our
#     present data since we could see its tumor volume actually decreasing while on that regimen.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import matplotlib.animation as animation

# Study data files
path = "../Nick/farmers_markets_from_usda.csv"

# Read the farmers market csv
farm_markert = pd.read_csv(path)
farm_markert
# Out:
#          FMID                                        MarketName  \
# 0     1018261   Caledonia Farmers Market Association - Danville
# 1     1018318                 Stearns Homestead Farmers' Market
# 2     1009364                 106 S. Main Street Farmers Market
# 3     1010691               10th Steet Community Farmers Market
# 4     1002454                              112st Madison Avenue
# ...       ...                                               ...
# 8799  1004767                    Zia Bernalillo Farmers' Market
# 8800  1018362                         Zimmerman Farmers' Market
# 8801  1012380                        Zion Canyon Farmers Market
# 8802  1004686                         Zionsville Farmers Market
# 8803  1011418                         Zona Rosa Farmers' Market
#
#                                                 Website  \
# 0     https://sites.google.com/site/caledoniafarmers...
# 1                       http://www.StearnsHomestead.com
# 2                http://thetownofsixmile.wordpress.com/
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8799                         http://www.eatfreshnm.org/
# 8800                         http://Pzfarmersmarket.org
# 8801                             http://zionharvest.org
# 8802             http://www.zionsvillefarmersmarket.org
# 8803                                                NaN
#
#                                                Facebook Twitter Youtube  \
# 0     https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                         StearnsHomesteadFarmersMarket     NaN     NaN
# 2                                                   NaN     NaN     NaN
# 3                                                   NaN     NaN     NaN
# 4                                                   NaN     NaN     NaN
# ...                                                 ...     ...     ...
# 8799   https://www.facebook.com/farmersmarketsnm?ref=hl     NaN     NaN
# 8800                 Princeton-zimmerman farmers market     NaN     NaN
# 8801  https://www.facebook.com/ZionCanyonFarmersMarket/     NaN     NaN
# 8802                                                NaN     NaN     NaN
# 8803                                                NaN     NaN     NaN
#
#                                              OtherMedia  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     http://agrimissouri.com/mo-grown/grodetail.php...
# 4                                                   NaN
# ...                                                 ...
# 8799                                                NaN
# 8800                                                NaN
# 8801                                                NaN
# 8802                                                NaN
# 8803                                                NaN
#
#                           street         city      County  ... Coffee Beans  \
# 0                            NaN     Danville   Caledonia  ...      Y     Y
# 1                6975 Ridge Road       Parma     Cuyahoga  ...      N     N
# 2             106 S. Main Street     Six Mile     Pickens  ...    NaN   NaN
# 3         10th Street and Poplar       Lamar       Barton  ...      N     N
# 4           112th Madison Avenue     New York    New York  ...      N     N
# ...                          ...          ...         ...  ...    ...   ...
# 8799    335 S. Camino del Pueblo   Bernalillo    Sandoval  ...      N     Y
# 8800           25850 Main Street   Zimmerman    Sherburne  ...      N     N
# 8801        1212 Zion Park Blvd.   Springdale  Washington  ...      Y     N
# 8802     Hawthorne & Main Street   Zionsville       Boone  ...    NaN   NaN
# 8803  Off of I-29 and Barry Road  Kansas City      Platte  ...      N     N
#
#      Fruits Grains Juices Mushrooms PetFood Tofu WildHarvested  \
# 0         Y      N      N         Y       Y    N             N
# 1         Y      N      N         N       N    N             N
# 2       NaN    NaN    NaN       NaN     NaN  NaN           NaN
# 3         Y      N      N         N       N    N             N
# 4         N      N      N         N       N    N             N
# ...     ...    ...    ...       ...     ...  ...           ...
# 8799      Y      N      N         N       N    N             N
# 8800      Y      N      N         N       N    N             N
# 8801      Y      N      N         Y       N    N             N
# 8802    NaN    NaN    NaN       NaN     NaN  NaN           NaN
# 8803      Y      N      N         N       N    N             N
#
#            updateTime
# 0     6/20/2017 22:43
# 1     6/21/2017 17:15
# 2                2013
# 3     10/28/2014 9:49
# 4      3/1/2012 10:38
# ...               ...
# 8799   6/5/2014 14:40
# 8800  6/22/2017 19:37
# 8801   7/9/2016 17:00
# 8802             2009
# 8803    9/4/2015 9:48
#
# [8804 rows x 59 columns]

# %%
state =["California" , "New York" , "Washington" , "Massachusetts"]
place = farm_markert.set_index("State")
state_df = place.loc[state]
state_df
# Out:
#                   FMID                               MarketName  \
# State
# California     1005272          Adelanto Stadium Farmers Market
# California     1009019                  Alameda Farmers' Market
# California     1008835         Alisal Certified Farmers' Market
# California     1009998                 Altadena Farmers' Market
# California     1011421        Alum Rock Village Farmers' Market
# ...                ...                                      ...
# Massachusetts  1006893                    Woburn Farmers Market
# Massachusetts  1008931            Woburn Indoor Farmers Market
# Massachusetts  1007624  Worcester Northeast Side Farmers Market
# Massachusetts  1002569                     Worcester/Main South
# Massachusetts  1007728                  Worcester/UMass Medical
#
#                                                      Website  \
# State
# California                                               NaN
# California                              http://www.pcfma.com
# California                   http://www.everyonesharvest.org
# California              http://www.altadenafarmersmarket.com
# California                              http://www.pcfma.org
# ...                                                      ...
# Massachusetts             http://www.woburnfarmersmarket.com
# Massachusetts             http://www.woburnfarmersmarket.com
# Massachusetts                                            NaN
# Massachusetts                                            NaN
# Massachusetts  http://www.greaterworcesterfarmersmarkets.org
#
#                                                         Facebook  \
# State
# California                                                   NaN
# California         https://www.facebook.com/AlamedaFarmersMarket
# California             https://www.facebook.com/EveryonesHarvest
# California        https://www.facebook.com/AltadenaFarmersMarket
# California         www.facebook.com/AlumRockVillageFarmersMarket
# ...                                                          ...
# Massachusetts  https://www.facebook.com/woburnfarmersmarket?r...
# Massachusetts  https://www.facebook.com/woburnfarmersmarket?r...
# Massachusetts                                                NaN
# Massachusetts                                                NaN
# Massachusetts                                                NaN
#
#                                        Twitter Youtube  \
# State
# California                                 NaN     NaN
# California                                 NaN     NaN
# California                                 NaN     NaN
# California      https://twitter.com/AltadenaFM     NaN
# California     www.twitter.com/PacCoastFarmers     NaN
# ...                                        ...     ...
# Massachusetts                              NaN     NaN
# Massachusetts                              NaN     NaN
# Massachusetts                              NaN     NaN
# Massachusetts                              NaN     NaN
# Massachusetts                              NaN     NaN
#
#                                  OtherMedia  \
# State
# California                              NaN
# California                              NaN
# California                              NaN
# California     http://altadenafm.tumblr.com
# California                              NaN
# ...                                     ...
# Massachusetts    www.tinyurl.com/spencefarm
# Massachusetts    www.tinyurl.com/spencefarm
# Massachusetts                           NaN
# Massachusetts                           NaN
# Massachusetts                           NaN
#
#                                                         street         city  \
# State
# California                              Hwy 395 & Rancho Drive  Victorville
# California                              Haight and Webster St.      Alameda
# California                              632 East Alisal Street      Salinas
# California                                  600 W. Palm Street     Altadena
# California                                 57 North White Road     San Jose
# ...                                                        ...          ...
# Massachusetts                                  41 Wyman Street       Woburn
# Massachusetts                                  41 Wyman Street       Woburn
# Massachusetts  Salem Covenant Church, 215 East Mountain Street    Worcester
# Massachusetts                                  766 Main Street    Worcester
# Massachusetts                                51 Lake Ave North    Worcester
#
#                        County  ... Coffee Beans Fruits Grains Juices  \
# State                          ...
# California     San Bernardino  ...    NaN   NaN    NaN    NaN    NaN
# California            Alameda  ...      N     N      Y      N      N
# California           Monterey  ...      N     N      Y      N      N
# California        Los Angeles  ...      Y     N      Y      Y      Y
# California        Santa Clara  ...      Y     N      Y      N      N
# ...                       ...  ...    ...   ...    ...    ...    ...
# Massachusetts       Middlesex  ...      N     N      Y      N      N
# Massachusetts       Middlesex  ...      N     N      Y      N      N
# Massachusetts       Worcester  ...    NaN   NaN    NaN    NaN    NaN
# Massachusetts       Worcester  ...      N     N      N      N      N
# Massachusetts       Worcester  ...    NaN   NaN    NaN    NaN    NaN
#
#               Mushrooms PetFood Tofu WildHarvested       updateTime
# State
# California          NaN     NaN  NaN           NaN             2009
# California            N       N    N             N  6/27/2016 12:57
# California            N       N    N             N  6/27/2016 15:24
# California            Y       N    N             N  4/22/2014 13:29
# California            N       N    N             N  7/20/2015 12:39
# ...                 ...     ...  ...           ...              ...
# Massachusetts         N       N    N             N   7/27/2013 9:49
# Massachusetts         N       N    N             N  7/27/2013 10:05
# Massachusetts       NaN     NaN  NaN           NaN             2009
# Massachusetts         N       N    N             N  5/24/2012 16:06
# Massachusetts       NaN     NaN  NaN           NaN             2011
#
# [1935 rows x 58 columns]

# %%
state_df.to_csv("../Nick/clean_farm.csv")
